# %% [markdown]
# # Release notes
#
# Render notebooks with **styled titles**, padding and alignment.

# %%
versions = {"cli": "0.0.3", "art": "0.0.3"}
print(versions)
# Out:
# {'cli': '0.0.3', 'art': '0.0.3'}
